# %% [markdown]
# <a href="https://colab.research.google.com/github/kanchan874/pattern_recognition/blob/main/Prelab_PR_CM23004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

print("Python Version:", sys.version)
# Out:
# Python Version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import cv2
import tensorflow as tf

print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("Scikit-Learn Version:", sklearn.__version__)
print("OpenCV Version:", cv2.__version__)
print("TensorFlow Version:", tf.__version__)
# Out:
# NumPy Version: 2.0.2
# Pandas Version: 2.2.2
# Scikit-Learn Version: 1.6.1
# OpenCV Version: 4.13.0
# TensorFlow Version: 2.20.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

print("Dataset Loaded Successfully")
print("Features:", iris.feature_names)
# Out:
# Dataset Loaded Successfully
# Features: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

print("DataFrame Created Successfully")
# Out:
# DataFrame Created Successfully

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    df['sepal length (cm)'],
    df['sepal width (cm)']
)

plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Iris Dataset')

plt.show()

# %%
print("All Libraries Installed Successfully")
print("Dataset Loaded Successfully")
print("Visualization Generated Successfully")
# Out:
# All Libraries Installed Successfully
# Dataset Loaded Successfully
# Visualization Generated Successfully
